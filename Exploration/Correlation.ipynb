# %%
import pandas as pd
import os
from pathlib import Path
import matplotlib.pyplot as plt
import datetime

read_path = r'C:\Users\Julia\Documents\Uni\Master\1\Data-Literacy\Daten\joined_survey_article_standardized_median.csv'
df = pd.read_csv(read_path, delimiter=';', header=0)
df["date"] = pd.to_datetime(df["date"], format="%d.%m.%Y")
df["SPD"] = pd.to_numeric(df["SPD"], errors='coerce')
df["Union"] = pd.to_numeric(df["Union"], errors='coerce')
df["Grüne"] = pd.to_numeric(df["Grüne"], errors='coerce')
df["FDP"] = pd.to_numeric(df["FDP"], errors='coerce')
df["AfD"] = pd.to_numeric(df["AfD"], errors='coerce')
df["Linke"] = pd.to_numeric(df["Linke"], errors='coerce')

# %%
df
# Out:
#      Unnamed: 0       date   SPD  Union  Grüne  FDP   AfD  Linke FW Andere  \
# 0             0 2023-12-22  14.0   32.0   14.0  5.0  21.0    3.0  4      7
# 1             1 2023-12-07  14.0   32.0   15.0  4.0  21.0    3.0  3      8
# 2             2 2023-11-10  15.0   30.0   15.0  5.0  21.0    4.0  3      7
# 3             3 2023-11-02  16.0   30.0   14.0  4.0  22.0    5.0  3      6
# 4             4 2023-10-13  15.0   29.0   13.0  5.0  23.0    4.0  4      7
# ..          ...        ...   ...    ...    ...  ...   ...    ... ..    ...
# 685         685 2000-07-01  39.0   38.0    6.0  8.0   NaN    5.0  -      4
# 686         686 2000-06-01  38.0   39.0    7.0  9.0   NaN    5.0  -      2
# 687         687 2000-05-01  41.0   36.0    6.0  7.0   NaN    5.0  -      5
# 688         688 2000-04-07  39.0   34.0    8.0  7.0   NaN    7.0  -      5
# 689         689 2000-03-03  42.0   31.0    7.0  9.0   NaN    7.0  -      4
#
#      standardized_war_articles
# 0                     0.149730
# 1                     0.169740
# 2                     0.193503
# 3                     0.179060
# 4                     0.195236
# ..                         ...
# 685                   0.008333
# 686                   0.015557
# 687                   0.027951
# 688                   0.014863
# 689                   0.000000
#
# [690 rows x 11 columns]

# %%
correlation_matrix = df.corr()
correlation_matrix
# Out:
# C:\Users\Julia\AppData\Local\Temp\ipykernel_12004\868109210.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlation_matrix = df.corr()
#                            Unnamed: 0       SPD     Union     Grüne       FDP  \
# Unnamed: 0                   1.000000  0.790215  0.704783 -0.613996  0.106899
# SPD                          0.790215  1.000000  0.445705 -0.670112 -0.019615
# Union                        0.704783  0.445705  1.000000 -0.587615 -0.308989
# Grüne                       -0.613996 -0.670112 -0.587615  1.000000 -0.122157
# FDP                          0.106899 -0.019615 -0.308989 -0.122157  1.000000
# AfD                         -0.744787 -0.653440 -0.731224  0.357925  0.436607
# Linke                       -0.209843 -0.155073 -0.264622 -0.028808  0.317068
# standardized_war_articles   -0.128824 -0.102354 -0.004192  0.067167 -0.150001
#
#                                 AfD     Linke  standardized_war_articles
# Unnamed: 0                -0.744787 -0.209843                  -0.128824
# SPD                       -0.653440 -0.155073                  -0.102354
# Union                     -0.731224 -0.264622                  -0.004192
# Grüne                      0.357925 -0.028808                   0.067167
# FDP                        0.436607  0.317068                  -0.150001
# AfD                        1.000000 -0.329152                   0.156412
# Linke                     -0.329152  1.000000                  -0.293275
# standardized_war_articles  0.156412 -0.293275                   1.000000

# %%
# 2003: januray -> january, february, march, april -> Irakkrieg
filtered_data = df.loc[df["date"].dt.year == 2003]
correlation_matrix = filtered_data.corr()
correlation_matrix
# Out:
# C:\Users\Julia\AppData\Local\Temp\ipykernel_12004\4114886701.py:3: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlation_matrix = filtered_data.corr()
#                            Unnamed: 0       SPD     Union     Grüne       FDP  \
# Unnamed: 0                   1.000000  0.515378 -0.340105  0.161272 -0.139239
# SPD                          0.515378  1.000000 -0.907977 -0.408637 -0.027309
# Union                       -0.340105 -0.907977  1.000000  0.393945 -0.209666
# Grüne                        0.161272 -0.408637  0.393945  1.000000 -0.313670
# FDP                         -0.139239 -0.027309 -0.209666 -0.313670  1.000000
# AfD                               NaN       NaN       NaN       NaN       NaN
# Linke                       -0.238186  0.125225 -0.236011 -0.549350  0.239064
# standardized_war_articles    0.785330  0.395786 -0.209995  0.210198 -0.402991
#
#                            AfD     Linke  standardized_war_articles
# Unnamed: 0                 NaN -0.238186                   0.785330
# SPD                        NaN  0.125225                   0.395786
# Union                      NaN -0.236011                  -0.209995
# Grüne                      NaN -0.549350                   0.210198
# FDP                        NaN  0.239064                  -0.402991
# AfD                        NaN       NaN                        NaN
# Linke                      NaN  1.000000                  -0.392344
# standardized_war_articles  NaN -0.392344                   1.000000

# %%
# (2006: August -> zweiter Libanonkrieg)
filtered_data = df.loc[df["date"].dt.year == 2006]
correlation_matrix = filtered_data.corr()
correlation_matrix
# Out:
# C:\Users\Julia\AppData\Local\Temp\ipykernel_12004\771958481.py:3: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlation_matrix = filtered_data.corr()
#                            Unnamed: 0       SPD     Union     Grüne       FDP  \
# Unnamed: 0                   1.000000  0.212741  0.869591 -0.765247 -0.826132
# SPD                          0.212741  1.000000  0.027313 -0.162098 -0.444054
# Union                        0.869591  0.027313  1.000000 -0.727094 -0.861152
# Grüne                       -0.765247 -0.162098 -0.727094  1.000000  0.611658
# FDP                         -0.826132 -0.444054 -0.861152  0.611658  1.000000
# AfD                               NaN       NaN       NaN       NaN       NaN
# Linke                       -0.276032 -0.197485 -0.505418  0.048154  0.463787
# standardized_war_articles   -0.199321 -0.449407 -0.168954  0.202163  0.335644
#
#                            AfD     Linke  standardized_war_articles
# Unnamed: 0                 NaN -0.276032                  -0.199321
# SPD                        NaN -0.197485                  -0.449407
# Union                      NaN -0.505418                  -0.168954
# Grüne                      NaN  0.048154                   0.202163
# FDP                        NaN  0.463787                   0.335644
# AfD                        NaN       NaN                        NaN
# Linke                      NaN  1.000000                   0.219524
# standardized_war_articles  NaN  0.219524                   1.000000

# %%
# # (2008: August -> Russland und Georgien)
filtered_data = df.loc[df["date"].dt.year == 2008]
correlation_matrix = filtered_data.corr()
correlation_matrix
# Out:
# C:\Users\Julia\AppData\Local\Temp\ipykernel_12004\1144346989.py:3: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlation_matrix = filtered_data.corr()
#                            Unnamed: 0       SPD     Union     Grüne       FDP  \
# Unnamed: 0                   1.000000  0.806576  0.528629 -0.492541 -0.804076
# SPD                          0.806576  1.000000  0.671506 -0.841295 -0.830720
# Union                        0.528629  0.671506  1.000000 -0.529927 -0.813294
# Grüne                       -0.492541 -0.841295 -0.529927  1.000000  0.548483
# FDP                         -0.804076 -0.830720 -0.813294  0.548483  1.000000
# AfD                               NaN       NaN       NaN       NaN       NaN
# Linke                       -0.324691 -0.606969 -0.663170  0.432414  0.499309
# standardized_war_articles   -0.283108 -0.214986 -0.038328 -0.063081  0.244966
#
#                            AfD     Linke  standardized_war_articles
# Unnamed: 0                 NaN -0.324691                  -0.283108
# SPD                        NaN -0.606969                  -0.214986
# Union                      NaN -0.663170                  -0.038328
# Grüne                      NaN  0.432414                  -0.063081
# FDP                        NaN  0.499309                   0.244966
# AfD                        NaN       NaN                        NaN
# Linke                      NaN  1.000000                   0.301470
# standardized_war_articles  NaN  0.301470                   1.000000

# %%
# 2009: januray -> Operation Gegossenes Blei, Israel und der Hamas im Gazastreifen.
filtered_data = df.loc[df["date"].dt.year == 2009]
correlation_matrix = filtered_data.corr()
correlation_matrix
# Out:
# C:\Users\Julia\AppData\Local\Temp\ipykernel_12004\572101415.py:3: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlation_matrix = filtered_data.corr()
#                            Unnamed: 0       SPD     Union     Grüne       FDP  \
# Unnamed: 0                   1.000000  0.713382 -0.236369 -0.570584  0.526656
# SPD                          0.713382  1.000000 -0.406908 -0.609322  0.184767
# Union                       -0.236369 -0.406908  1.000000  0.390405 -0.471611
# Grüne                       -0.570584 -0.609322  0.390405  1.000000 -0.273549
# FDP                          0.526656  0.184767 -0.471611 -0.273549  1.000000
# AfD                               NaN       NaN       NaN       NaN       NaN
# Linke                       -0.467571 -0.410415 -0.312522 -0.132936 -0.260272
# standardized_war_articles    0.238413  0.162255  0.255722 -0.370394 -0.331540
#
#                            AfD     Linke  standardized_war_articles
# Unnamed: 0                 NaN -0.467571                   0.238413
# SPD                        NaN -0.410415                   0.162255
# Union                      NaN -0.312522                   0.255722
# Grüne                      NaN -0.132936                  -0.370394
# FDP                        NaN -0.260272                  -0.331540
# AfD                        NaN       NaN                        NaN
# Linke                      NaN  1.000000                   0.131748
# standardized_war_articles  NaN  0.131748                   1.000000

# %%
# 2014: July, august -> Juli 2014 begann der Konflikt in der Ukraine zwischen pro-russischen Separatisten
# what about march, may? -> many different articles related to more unknown wars / more minor confrontations (Südkorea, Irak, Lybien)
filtered_data = df.loc[df["date"].dt.year == 2014]
correlation_matrix = filtered_data.corr()
correlation_matrix
# Out:
# C:\Users\Julia\AppData\Local\Temp\ipykernel_12004\1298676154.py:4: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlation_matrix = filtered_data.corr()
#                            Unnamed: 0       SPD     Union     Grüne       FDP  \
# Unnamed: 0                   1.000000  0.391041  0.092019 -0.227471  0.816548
# SPD                          0.391041  1.000000 -0.108229 -0.170282  0.300497
# Union                        0.092019 -0.108229  1.000000 -0.562533 -0.075421
# Grüne                       -0.227471 -0.170282 -0.562533  1.000000  0.119523
# FDP                          0.816548  0.300497 -0.075421  0.119523  1.000000
# AfD                         -0.679629 -0.440928 -0.378007  0.117468 -0.714590
# Linke                       -0.191521 -0.387475 -0.259470 -0.148109 -0.276887
# standardized_war_articles   -0.089114 -0.204927  0.065905 -0.040660 -0.027683
#
#                                 AfD     Linke  standardized_war_articles
# Unnamed: 0                -0.679629 -0.191521                  -0.089114
# SPD                       -0.440928 -0.387475                  -0.204927
# Union                     -0.378007 -0.259470                   0.065905
# Grüne                      0.117468 -0.148109                  -0.040660
# FDP                       -0.714590 -0.276887                  -0.027683
# AfD                        1.000000  0.363846                  -0.288204
# Linke                      0.363846  1.000000                   0.422924
# standardized_war_articles -0.288204  0.422924                   1.000000

# %%
# 2022: all year -> verschiedene Konflikte, Russland und Ukraine -> way more articles than 2023
filtered_data = df.loc[df["date"].dt.year == 2022]
correlation_matrix = filtered_data.corr()
correlation_matrix
# Out:
# C:\Users\Julia\AppData\Local\Temp\ipykernel_12004\2883120713.py:3: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlation_matrix = filtered_data.corr()
#                            Unnamed: 0       SPD     Union     Grüne       FDP  \
# Unnamed: 0                   1.000000  0.881718 -0.818854 -0.492761  0.936688
# SPD                          0.881718  1.000000 -0.805547 -0.690570  0.802797
# Union                       -0.818854 -0.805547  1.000000  0.358853 -0.830440
# Grüne                       -0.492761 -0.690570  0.358853  1.000000 -0.470509
# FDP                          0.936688  0.802797 -0.830440 -0.470509  1.000000
# AfD                         -0.820947 -0.725908  0.659248  0.091550 -0.754066
# Linke                       -0.109756 -0.123656  0.084029 -0.397304 -0.082606
# standardized_war_articles    0.210704  0.373869 -0.093665 -0.067480  0.085124
#
#                                 AfD     Linke  standardized_war_articles
# Unnamed: 0                -0.820947 -0.109756                   0.210704
# SPD                       -0.725908 -0.123656                   0.373869
# Union                      0.659248  0.084029                  -0.093665
# Grüne                      0.091550 -0.397304                  -0.067480
# FDP                       -0.754066 -0.082606                   0.085124
# AfD                        1.000000  0.528816                  -0.429383
# Linke                      0.528816  1.000000                  -0.425806
# standardized_war_articles -0.429383 -0.425806                   1.000000

# %%
# 2023: all year -> verschiedene Konflikte, Russland und Ukraine
filtered_data = df.loc[df["date"].dt.year == 2023]
correlation_matrix = filtered_data.corr()
correlation_matrix
# Out:
# C:\Users\Julia\AppData\Local\Temp\ipykernel_12004\1900310182.py:3: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlation_matrix = filtered_data.corr()
#                            Unnamed: 0       SPD     Union     Grüne       FDP  \
# Unnamed: 0                   1.000000  0.899283 -0.218245  0.836782  0.530222
# SPD                          0.899283  1.000000 -0.478375  0.641445  0.666250
# Union                       -0.218245 -0.478375  1.000000  0.036633 -0.625559
# Grüne                        0.836782  0.641445  0.036633  1.000000  0.220498
# FDP                          0.530222  0.666250 -0.625559  0.220498  1.000000
# AfD                         -0.920654 -0.783576 -0.078512 -0.871876 -0.421168
# Linke                        0.559234  0.480325 -0.129391  0.365387  0.268557
# standardized_war_articles   -0.250284 -0.326159  0.425614 -0.029907 -0.563520
#
#                                 AfD     Linke  standardized_war_articles
# Unnamed: 0                -0.920654  0.559234                  -0.250284
# SPD                       -0.783576  0.480325                  -0.326159
# Union                     -0.078512 -0.129391                   0.425614
# Grüne                     -0.871876  0.365387                  -0.029907
# FDP                       -0.421168  0.268557                  -0.563520
# AfD                        1.000000 -0.495557                   0.089410
# Linke                     -0.495557  1.000000                  -0.009026
# standardized_war_articles  0.089410 -0.009026                   1.000000
